# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
plt.hist(df['sepal_length'])
plt.title('Histogram of sepal lemgth')
# Out:
# Text(0.5, 1.0, 'Histogram of sepal lemgth')

# %%
plt.hist(df['sepal_width'])
plt.title('Histogram of sepal width')
# Out:
# Text(0.5, 1.0, 'Histogram of sepal width')

# %%
plt.hist(df['petal_length'])
plt.title('Histogram of petal length ')
# Out:
# Text(0.5, 1.0, 'Histogram of petal length ')

# %%
plt.hist(df['petal_width'])
plt.title('Histogram of petal length')
# Out:
# Text(0.5, 1.0, 'Histogram of petal length')

# %%
plt.hist(df['species'])
plt.title('Histogram of species')
# Out:
# Text(0.5, 1.0, 'Histogram of species')

# %%
plt.boxplot(df['sepal_length'])
plt.title('Boxplot of Sepal Length')
# Out:
# Text(0.5, 1.0, 'Boxplot of Sepal Length')

# %%
plt.boxplot(df['sepal_width'])
plt.title("Boxplot of Sepal Width")
# Out:
# Text(0.5, 1.0, 'Boxplot of Sepal Width')

# %%
plt.boxplot(df['petal_width'])
plt.title("Boxplot of Petal Width")
# Out:
# Text(0.5, 1.0, 'Boxplot of Petal Width')

# %%
plt.boxplot(df['petal_length'])
plt.title("Boxplot of Petal Length")
# Out:
# Text(0.5, 1.0, 'Boxplot of Petal Length')

# %%
fig,axes=plt.subplots(2,2,figsize=(16,8))
axes[0,0].set_title("Distribution of first column")
axes[0,0].hist(df["sepal_length"]);
axes[0,1].set_title("Distribution of second column")
axes[0,1].hist(df["sepal_width"]);
axes[1,0].set_title("Distribution of third column")
axes[1,0].hist(df["petal_width"]);
axes[1,1].set_title("Distribution of forth column")
axes[1,1].hist(df["petal_length"]);

# %%
fig,axes=plt.subplots(2,2,figsize=(16,8))
axes[0,0].set_title("Distribution of first column")
axes[0,0].boxplot(df["sepal_length"]);
axes[0,1].set_title("Distribution of second column")
axes[0,1].boxplot(df["sepal_width"]);
axes[1,0].set_title("Distribution of third column")
axes[1,0].boxplot(df["petal_width"]);
axes[1,1].set_title("Distribution of forth column")
axes[1,1].boxplot(df["petal_length"]);

# %%
import numpy as np
threshold = 3  # Adjust the threshold as needed

z_scores = np.abs((df - df.mean()) / df.std())
outliers = z_scores > threshold

print("Outliers:")
print(outliers.any(axis=0))
# Out:
# Outliers:
# petal_length    False
# petal_width     False
# sepal_length    False
# sepal_width      True
# species         False
# dtype: bool
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11676\3267192783.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   z_scores = np.abs((df - df.mean()) / df.std())
