# %%
import pandas as pd

# %%
data=pd.read_csv("student.csv")

# %%
data
# Out:
#    Name  Rollno  Marks
# 0     A       1   78.0
# 1     B       2   65.0
# 2     C       3   54.0
# 3     D       4    NaN
# 4     E       5   67.0
# 5     F       6    NaN
# 6     H       7   56.0
# 7     I       8   34.0
# 8     J       9    NaN
# 9     K      10   45.0
# 10    L      11   65.0
# 11    M      12   54.0
# 12    N      13    NaN
# 13    O      14   43.0
# 14    P      15    NaN

# %%
data.shape
# Out:
# (15, 3)

# %%
data.isnull()
# Out:
#      Name  Rollno  Marks
# 0   False   False  False
# 1   False   False  False
# 2   False   False  False
# 3   False   False   True
# 4   False   False  False
# 5   False   False   True
# 6   False   False  False
# 7   False   False  False
# 8   False   False   True
# 9   False   False  False
# 10  False   False  False
# 11  False   False  False
# 12  False   False   True
# 13  False   False  False
# 14  False   False   True

# %%
data.isnull().sum()
# Out:
# Name      0
# Rollno    0
# Marks     5
# dtype: int64

# %%
data1=data.fillna(value=0)

# %%
data1
# Out:
#    Name  Rollno  Marks
# 0     A       1   78.0
# 1     B       2   65.0
# 2     C       3   54.0
# 3     D       4    0.0
# 4     E       5   67.0
# 5     F       6    0.0
# 6     H       7   56.0
# 7     I       8   34.0
# 8     J       9    0.0
# 9     K      10   45.0
# 10    L      11   65.0
# 11    M      12   54.0
# 12    N      13    0.0
# 13    O      14   43.0
# 14    P      15    0.0

# %%
data1.isnull()
# Out:
#      Name  Rollno  Marks
# 0   False   False  False
# 1   False   False  False
# 2   False   False  False
# 3   False   False  False
# 4   False   False  False
# 5   False   False  False
# 6   False   False  False
# 7   False   False  False
# 8   False   False  False
# 9   False   False  False
# 10  False   False  False
# 11  False   False  False
# 12  False   False  False
# 13  False   False  False
# 14  False   False  False

# %%
data_mean=data['Marks'].mean()

# %%
data_mean
# Out:
# 56.1

# %%
data2=data.fillna(value=data_mean)

# %%
data2
# Out:
#    Name  Rollno  Marks
# 0     A       1   78.0
# 1     B       2   65.0
# 2     C       3   54.0
# 3     D       4   56.1
# 4     E       5   67.0
# 5     F       6   56.1
# 6     H       7   56.0
# 7     I       8   34.0
# 8     J       9   56.1
# 9     K      10   45.0
# 10    L      11   65.0
# 11    M      12   54.0
# 12    N      13   56.1
# 13    O      14   43.0
# 14    P      15   56.1

# %%
data_median=data['Marks'].median()

# %%
data_median
# Out:
# 55.0

# %%
data4=data.fillna(value=data_median)

# %%
 data4
# Out:
#    Name  Rollno  Marks
# 0     A       1   78.0
# 1     B       2   65.0
# 2     C       3   54.0
# 3     D       4   55.0
# 4     E       5   67.0
# 5     F       6   55.0
# 6     H       7   56.0
# 7     I       8   34.0
# 8     J       9   55.0
# 9     K      10   45.0
# 10    L      11   65.0
# 11    M      12   54.0
# 12    N      13   55.0
# 13    O      14   43.0
# 14    P      15   55.0

# %%
data_min=data['Marks'].min()

# %%
data_min
# Out:
# 34.0

# %%
data5=data.fillna(value=data_min)

# %%
 data5
# Out:
#    Name  Rollno  Marks
# 0     A       1   78.0
# 1     B       2   65.0
# 2     C       3   54.0
# 3     D       4   34.0
# 4     E       5   67.0
# 5     F       6   34.0
# 6     H       7   56.0
# 7     I       8   34.0
# 8     J       9   34.0
# 9     K      10   45.0
# 10    L      11   65.0
# 11    M      12   54.0
# 12    N      13   34.0
# 13    O      14   43.0
# 14    P      15   34.0

# %%
data_max=data['Marks'].max()

# %%
data_max
# Out:
# 78.0

# %%
data6=data.fillna(value=data_max)

# %%
data6
# Out:
#    Name  Rollno  Marks
# 0     A       1   78.0
# 1     B       2   65.0
# 2     C       3   54.0
# 3     D       4   78.0
# 4     E       5   67.0
# 5     F       6   78.0
# 6     H       7   56.0
# 7     I       8   34.0
# 8     J       9   78.0
# 9     K      10   45.0
# 10    L      11   65.0
# 11    M      12   54.0
# 12    N      13   78.0
# 13    O      14   43.0
# 14    P      15   78.0

# %%
data7=data.dropna()

# %%
data7
# Out:
#    Name  Rollno  Marks
# 0     A       1   78.0
# 1     B       2   65.0
# 2     C       3   54.0
# 4     E       5   67.0
# 6     H       7   56.0
# 7     I       8   34.0
# 9     K      10   45.0
# 10    L      11   65.0
# 11    M      12   54.0
# 13    O      14   43.0

# %%
data_row_null=data
data_row_null.at[2,'Name']=None
data_row_null.at[2,'Rollno']=None

# %%
data_row_null
# Out:
#     Name  Rollno  Marks
# 0      A     1.0   78.0
# 1      B     2.0   65.0
# 2   None     NaN   54.0
# 3      D     4.0    NaN
# 4      E     5.0   67.0
# 5      F     6.0    NaN
# 6      H     7.0   56.0
# 7      I     8.0   34.0
# 8      J     9.0    NaN
# 9      K    10.0   45.0
# 10     L    11.0   65.0
# 11     M    12.0   54.0
# 12     N    13.0    NaN
# 13     O    14.0   43.0
# 14     P    15.0    NaN

# %%
data8=data_row_null.dropna(how='all')

# %%
data8
# Out:
#     Name  Rollno  Marks
# 0      A     1.0   78.0
# 1      B     2.0   65.0
# 2   None     NaN   54.0
# 3      D     4.0    NaN
# 4      E     5.0   67.0
# 5      F     6.0    NaN
# 6      H     7.0   56.0
# 7      I     8.0   34.0
# 8      J     9.0    NaN
# 9      K    10.0   45.0
# 10     L    11.0   65.0
# 11     M    12.0   54.0
# 12     N    13.0    NaN
# 13     O    14.0   43.0
# 14     P    15.0    NaN

# %%
import pandas as pd

# %%
df=pd.read_csv("height.csv")

# %%
df
# Out:
#    Name  Height
# 0     A     2.0
# 1     B     5.4
# 2     C     4.3
# 3     D     3.4
# 4     E     5.4
# 5     F     5.2
# 6     G     4.5
# 7     H     5.5
# 8     I     5.1
# 9     J     4.2
# 10    K     5.9
# 11    L     6.0
# 12    M     4.9

# %%
df.describe()
# Out:
#           Height
# count  13.000000
# mean    4.753846
# std     1.102736
# min     2.000000
# 25%     4.300000
# 50%     5.100000
# 75%     5.400000
# max     6.000000

# %%
import matplotlib.pyplot as plt

# %%
x=df['Height']
plt.hist(x)
plt.show()

# %%
Q1=df.Height.quantile(0.25)
Q3=df.Height.quantile(0.75)
Q1,Q3
# Out:
# (4.3, 5.4)

# %%
IQR=Q3-Q1
IQR
# Out:
# 1.1000000000000005

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (2.649999999999999, 7.050000000000001)

# %%
df[(df.Height<lower_limit)|(df.Height>upper_limit)]
# Out:
#   Name  Height
# 0    A     2.0

# %%
df_outliers=df[(df.Height<lower_limit)|(df.Height>upper_limit)]
x=df_outliers['Height']
plt.hist(x)
plt.show()

# %%
df_no_outliers=df[(df.Height>lower_limit)&(df.Height<upper_limit)]
df_no_outliers
# Out:
#    Name  Height
# 1     B     5.4
# 2     C     4.3
# 3     D     3.4
# 4     E     5.4
# 5     F     5.2
# 6     G     4.5
# 7     H     5.5
# 8     I     5.1
# 9     J     4.2
# 10    K     5.9
# 11    L     6.0
# 12    M     4.9

# %%
x=df_no_outliers['Height']
plt.hist(x)
plt.show()

# %%
import numpy as np

# %%
d=pd.read_csv("ass2.csv")

# %%
print(d)
# Out:
#                Name  Age  Gender  Grade  Unnamed: 4  Maths  Unnamed: 6
# aa   23 male    NaN    A     NaN   56.0         NaN   67.0         NaN  \
# bb   19 female    B  NaN    54.0    NaN        91.0    NaN        67.0
# cc   18 female    C  NaN    67.0    NaN        78.0    NaN        67.0
# dd   23 male    NaN    D     NaN   78.0         NaN   68.0         NaN
# ee   21 male    NaN    A     NaN   67.0         NaN   68.0         NaN
# ff   20 female    C  NaN    78.0    NaN        78.0    NaN        57.0
# gg   21 male    NaN    B     NaN   68.0         NaN   68.0         NaN
#
#                 Science  English  Attendence
# aa   23 male       56.0      NaN        67.0
# bb   19 female      NaN     90.0         NaN
# cc   18 female      NaN     95.0         NaN
# dd   23 male       78.0      NaN        89.0
# ee   21 male       74.0      NaN        87.0
# ff   20 female      NaN     91.0         NaN
# gg   21 male       46.0      NaN        87.0

# %%
d['Attendnce_log']=np.log(d['Attendence'])
fig,axs=plt.subplots(1,2,figsize=(10,5))
axs[0].hist(d['Attendence'],bins=30)
axs[0].set_title('Attendnce distribution(before transformation)')
axs[1].hist(d['Attendnce_log'],bins=30)
axs[1].set_title('Attendnce distribution(after transformation)')
plt.show()
